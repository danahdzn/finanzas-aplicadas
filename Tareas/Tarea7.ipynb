# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Oct 27 10:48:58 2023

@author: Meva
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import importlib
import random
import scipy.optimize as op


# importar el archivo de soporte
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/ArchivosCSV/ArchivosAuxiliares')
import market_data
import capm
import portfolio

'''
El jueves le entregaste a tu gerente de portafolios el script 08_portfolios.py,
que está basado en el archivo de clase portfolio.py.

Ahora ella te pide una función que dada una lista de activos "rics",
calcule sus volatilidades.

Para lograrlo, vas a tener que usar la clase portfolio.manager
como soporte de tu código.
'''


def compute_volatilities(rics):
    notional = 15
    port_mgr = portfolio.manager(rics, notional)
    port_mgr.compute_covariance()
    volatilities = list(port_mgr.dataframe_metrics['volatilities'])
    return volatilities


# tests unitarios
def unit_test(rics, n):
    print('-----')
    print('Test ' + str(n))
    print('rics = ' + str(rics))
    print('Tu resultado es ' + str(compute_volatilities(rics)))


# tests unitarios
n = 1
rics = ['^SPX','^IXIC','^MXX','^STOXX','^GDAXI','^FCHI','^VIX']
unit_test(rics, n)
print('El resultado esperado es [0.183295 0.245508 0.148552 0.15365  0.183207 0.178846 1.203178]')

n += 1
rics = ['IVW','IVE','QUAL','MTUM','SIZE','USMV']
unit_test(rics, n)
print('El resultado esperado es [0.224872 0.158816 0.192721 0.211806 0.188777 0.139332]')

n += 1
rics = ['BTC-USD','ETH-USD','SOL-USD','USDC-USD','USDT-USD','DAI-USD']
unit_test(rics, n)
print('El resultado esperado es [0.555368 0.728856 1.10316  0.020744 0.011118 0.028805]')

n += 1
rics = ['EURUSD=X','GBPUSD=X','CHFUSD=X','SEKUSD=X','NOKUSD=X','JPYUSD=X','MXNUSD=X']
unit_test(rics, n)
print('El resultado esperado es [0.078729 0.094666 0.080449 0.115417 0.169989 0.094178 0.103517]')

n += 1
rics = ['^SPX','^IXIC','^MXX','^STOXX','^GDAXI','^FCHI','^VIX']
unit_test(rics, n)
print('El resultado esperado es [0.183295 0.245508 0.148552 0.15365  0.183207 0.178846 1.203178]')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# -----
# Test 1
# rics = ['^SPX', '^IXIC', '^MXX', '^STOXX', '^GDAXI', '^FCHI', '^VIX']
# Tu resultado es [0.183295, 0.245508, 0.148552, 0.15365, 0.183207, 0.178846, 1.203178]
# El resultado esperado es [0.183295 0.245508 0.148552 0.15365  0.183207 0.178846 1.203178]
# -----
# Test 2
# rics = ['IVW', 'IVE', 'QUAL', 'MTUM', 'SIZE', 'USMV']
# Tu resultado es [0.224872, 0.158816, 0.192721, 0.211806, 0.188777, 0.139332]
# El resultado esperado es [0.224872 0.158816 0.192721 0.211806 0.188777 0.139332]
# -----
# Test 3
# rics = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'USDC-USD', 'USDT-USD', 'DAI-USD']
# Tu resultado es [0.555368, 0.728856, 1.10316, 0.020744, 0.011118, 0.028805]
# El resultado esperado es [0.555368 0.728856 1.10316  0.020744 0.011118 0.028805]
# -----
# Test 4
# ...
